# %%
import pandas as pd

# %%
file_url = "https://bit.ly/ds01-weight-history"
data = pd.read_csv(file_url, index_col="회차")

data
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 4   강성희  2019-01-04   NaN  kg  최재우  여의도
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구
# 6   강성희  2019-01-06  75.7  kg  최재우  여의도
# 7   강성희  2019-01-07   NaN  kg  최재우  여의도
# 8   강성희  2019-01-08   NaN  kg  김민철  여의도
# 9   강성희  2019-01-09  75.0  kg  김민철  여의도

# %%
data.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6, 7, 8, 9], dtype='int64', name='회차')

# %%
data.columns
# Out:
# Index(['이름', '측정일', '몸무게', '단위', '담당', '지점'], dtype='object')

# %%
data.columns
# Out:
# Index(['이름', '측정일', '몸무게', '단위', '담당', '지점'], dtype='object')

# %%
data.shape
# Out:
# (9, 6)

# %%
data.head(2)
# Out:
#      이름         측정일   몸무게  단위   담당  지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수  강남
# 2   강성희  2019-01-02  75.7  kg  김지수  강남

# %%
data.tail(2)
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 8   강성희  2019-01-08   NaN  kg  김민철  여의도
# 9   강성희  2019-01-09  75.0  kg  김민철  여의도

# %% [markdown]
# ## 기본연산

# %%
data["몸무게"].mean()
# Out:
# 75.83333333333333

# %%
data["몸무게"].max()
# Out:
# 76.4

# %%
data["몸무게"].describe()
# Out:
# count     6.000000
# mean     75.833333
# std       0.492612
# min      75.000000
# 25%      75.700000
# 50%      75.850000
# 75%      76.150000
# max      76.400000
# Name: 몸무게, dtype: float64

# %%
data
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 4   강성희  2019-01-04   NaN  kg  최재우  여의도
# 5   강성희  2019-01-05  76.2  kg  김지수   강남
# 6   강성희  2019-01-06  75.7  kg  최재우  여의도
# 7   강성희  2019-01-07   NaN  kg  최재우  여의도
# 8   강성희  2019-01-08   NaN  kg  김민철  여의도
# 9   강성희  2019-01-09  75.0  kg  김민철  여의도

# %%
data["지점"] = data["지점"].replace("강남구","강남")

# %%
data["몸무게"] = data["몸무게"].fillna(75.8)

# %%
data["몸무게(prev)"] = data["몸무게"].shift(+1)

# %%
data["몸무게(next)"] = data["몸무게"].shift(-1)

# %%
data["측정일"] = pd.to_datetime(data["측정일"])

# %%
data["측정일"].dt.year
# Out:
# 회차
# 1    2019
# 2    2019
# 3    2019
# 4    2019
# 5    2019
# 6    2019
# 7    2019
# 8    2019
# 9    2019
# Name: 측정일, dtype: int64

# %% [markdown]
# ## 행열 검색

# %%
data[["이름","측정일","몸무게"]]
# Out:
#      이름        측정일   몸무게
# 회차
# 1   강성희 2019-01-01  76.4
# 2   강성희 2019-01-02  75.7
# 3   강성희 2019-01-03  76.0
# 4   강성희 2019-01-04  75.8
# 5   강성희 2019-01-05  76.2
# 6   강성희 2019-01-06  75.7
# 7   강성희 2019-01-07  75.8
# 8   강성희 2019-01-08  75.8
# 9   강성희 2019-01-09  75.0

# %%
data.loc[1]
# Out:
# 이름                           강성희
# 측정일          2019-01-01 00:00:00
# 몸무게                         76.4
# 단위                            kg
# 담당                           김지수
# 지점                            강남
# 몸무게(prev)                    NaN
# 몸무게(next)                   75.7
# Name: 1, dtype: object

# %%
data.loc[2]
# Out:
# 이름                           강성희
# 측정일          2019-01-02 00:00:00
# 몸무게                         75.7
# 단위                            kg
# 담당                           김지수
# 지점                            강남
# 몸무게(prev)                   76.4
# 몸무게(next)                     76
# Name: 2, dtype: object

# %%
data.loc[[1,2,3]]
# Out:
#      이름        측정일   몸무게  단위   담당  지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수  강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수  강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수  강남       75.7       75.8

# %%
data.loc[1:7]
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8

# %%
# %timeit data.loc[1,"이름"] # 퍼포먼스가 더 좋음
# Out:
# 8.33 µs ± 618 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit data.loc[1]["이름"]
# Out:
# 191 µs ± 12.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
data.loc[[1,3,7],["이름","측정일","몸무게"]] # 변수에 담아놓고 사용해야함
# Out:
#      이름        측정일   몸무게
# 회차
# 1   강성희 2019-01-01  76.4
# 3   강성희 2019-01-03  76.0
# 7   강성희 2019-01-07  75.8

# %%
# %timeit data.loc[1,"이름"]
# Out:
# 8.35 µs ± 105 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit data.at[1,"이름"]
# Out:
# 4.75 µs ± 52.7 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# ## 색인

# %%
data[data["담당"] == "김지수"]
# Out:
#      이름        측정일   몸무게  단위   담당  지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수  강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수  강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수  강남       75.7       75.8
# 5   강성희 2019-01-05  76.2  kg  김지수  강남       75.8       75.7

# %%
data[data["몸무게"] > 75 ]
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0

# %%
data[data["담당"].isin(["최지우","김민철"])]
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)
# 회차
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도       75.8        NaN

# %%
data[data["담당"].str.contains("김")]
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도       75.8        NaN

# %%
data[data["몸무게(prev)"].isnull()]
# Out:
#      이름        측정일   몸무게  단위   담당  지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수  강남        NaN       75.7

# %%
data[data["몸무게(prev)"].notnull()]
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)
# 회차
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도       75.8        NaN

# %%
data[(data["몸무게"] > 75) & (data["담당"].str.contains("김"))]
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0

# %%
high = data["몸무게"] > 75

# %%
kim = data["담당"].str.contains("김")

# %%
data[high & kim]
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0

# %%
data[high | kim]
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도       75.8        NaN

# %%
data.loc[high & kim,["몸무게","이름","측정일"]]
# Out:
#      몸무게   이름        측정일
# 회차
# 1   76.4  강성희 2019-01-01
# 2   75.7  강성희 2019-01-02
# 3   76.0  강성희 2019-01-03
# 5   76.2  강성희 2019-01-05
# 8   75.8  강성희 2019-01-08

# %% [markdown]
# ## 컬럼추가 수정

# %%
data["지역"] = "서울"

# %%
data
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)  지역
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7  서울
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0  서울
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8  서울
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2  서울
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7  서울
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8  서울
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8  서울
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0  서울
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도       75.8        NaN  서울

# %%
data["결제"] = [True,True,True,True,False,True,True,False,True]
data
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)  지역     결제
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7  서울   True
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0  서울   True
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8  서울   True
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2  서울   True
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7  서울  False
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8  서울   True
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8  서울   True
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0  서울  False
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도       75.8        NaN  서울   True

# %% [markdown]
# ## 피벗 테이블

# %%
pd.pivot_table(data,index=["지점","담당"],values="몸무게", aggfunc='sum')
# Out:
#            몸무게
# 지점  담당
# 강남  김지수  304.3
# 여의도 김민철  150.8
#     최재우  227.3

# %% [markdown]
# ## 본격적인 데이터 추가 및 수정

# %%
data["몸무게(gram)"] = data["몸무게"] * 1000

# %%
data["과체중"] = data["몸무게"] > 75.8

# %%
data.loc[ data["몸무게"] > 75.8 , "상태"]  = "과체중"

# %%
data.loc[ data["몸무게"] <=75.8 , "상태"]  = "정상"

# %%
data
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)  지역     결제  \
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7  서울   True
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0  서울   True
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8  서울   True
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2  서울   True
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7  서울  False
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8  서울   True
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8  서울   True
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0  서울  False
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도       75.8        NaN  서울   True
#
#     몸무게(gram)    과체중   상태
# 회차
# 1     76400.0   True  과체중
# 2     75700.0  False   정상
# 3     76000.0   True  과체중
# 4     75800.0  False   정상
# 5     76200.0   True  과체중
# 6     75700.0  False   정상
# 7     75800.0  False   정상
# 8     75800.0  False   정상
# 9     75000.0  False   정상

# %% [markdown]
# ## 컬럼삭제

# %%
data.drop("과체중",axis="columns")
# Out:
#      이름        측정일   몸무게  단위   담당   지점  몸무게(prev)  몸무게(next)  지역     결제  \
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남        NaN       75.7  서울   True
# 2   강성희 2019-01-02  75.7  kg  김지수   강남       76.4       76.0  서울   True
# 3   강성희 2019-01-03  76.0  kg  김지수   강남       75.7       75.8  서울   True
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도       76.0       76.2  서울   True
# 5   강성희 2019-01-05  76.2  kg  김지수   강남       75.8       75.7  서울  False
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도       76.2       75.8  서울   True
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도       75.7       75.8  서울   True
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도       75.8       75.0  서울  False
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도       75.8        NaN  서울   True
#
#     몸무게(gram)   상태
# 회차
# 1     76400.0  과체중
# 2     75700.0   정상
# 3     76000.0  과체중
# 4     75800.0   정상
# 5     76200.0  과체중
# 6     75700.0   정상
# 7     75800.0   정상
# 8     75800.0   정상
# 9     75000.0   정상

# %%
data = data.drop(["과체중","몸무게(prev)","몸무게(next)"],axis="columns")
data
# Out:
#      이름        측정일   몸무게  단위   담당   지점  지역     결제  몸무게(gram)   상태
# 회차
# 1   강성희 2019-01-01  76.4  kg  김지수   강남  서울   True    76400.0  과체중
# 2   강성희 2019-01-02  75.7  kg  김지수   강남  서울   True    75700.0   정상
# 3   강성희 2019-01-03  76.0  kg  김지수   강남  서울   True    76000.0  과체중
# 4   강성희 2019-01-04  75.8  kg  최재우  여의도  서울   True    75800.0   정상
# 5   강성희 2019-01-05  76.2  kg  김지수   강남  서울  False    76200.0  과체중
# 6   강성희 2019-01-06  75.7  kg  최재우  여의도  서울   True    75700.0   정상
# 7   강성희 2019-01-07  75.8  kg  최재우  여의도  서울   True    75800.0   정상
# 8   강성희 2019-01-08  75.8  kg  김민철  여의도  서울  False    75800.0   정상
# 9   강성희 2019-01-09  75.0  kg  김민철  여의도  서울   True    75000.0   정상
